# %%
import requests
from bs4 import BeautifulSoup 
import json
import pandas as pd

# %%
base_url = 'https://understat.com/league/EPL/'
season_names = ['2014', '2015', '2016', '2017', '2018','2019', '2020']

# %% [markdown]
# **getting data for EPL 2014**

# %%
url = base_url + season_names[0]
res = requests.get(url)
soup = BeautifulSoup(res.content, 'lxml')

# %%
# data is under "scripts" tag. So, finding all the script tags

# %%
script = soup.find_all('script')
# print(script)

# %%
string_with_json_obj = ''

for el in script:
    if 'teamsData' in el.text:
        string_with_json_obj = el.text.strip()
# print(string_with_json_obj)

# %%
#keeping only the part of string we need
ind_start = string_with_json_obj.index("('") + 2
ind_end = string_with_json_obj.index("')") 
json_data = string_with_json_obj[ind_start: ind_end]

json_data = json_data.encode('utf8').decode('unicode_escape')

# %%
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "202": {
#         "history": [
#             {
#                 "date": "2014-08-16 15:00:00",
#                 "deep": 1,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 1.12689,
#                 "npxGA": 1.11757,
#                 "npxGD": 0.009319999999999995,
#                 "ppda": {
#                     "att": 218,
#                     "def": 17
#                 },
#                 "ppda_allowed": {
#                     "att": 216,
#                     "def": 21
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.90067,
#                 "xGA": 1.11757,
#                 "xpts": 2.0149
#             },
#             {
#                 "date": "2014-08-24 13:30:00",
#                 "deep": 2,
#                 "deep_allowed": 8,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 4,
#                 "npxG": 1.07617,
#                 "npxGA": 2.38894,
#                 "npxGD": -1.3127699999999998,
#                 "ppda": {
#                     "att": 456,
#                     "def": 28
#                 },
#                 "ppda_allowed": {
#                     "att": 224,
#                     "def": 29
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.07617,
#                 "xGA": 2.38894,
#                 "xpts": 0.5381
#             },
#             {
#                 "date": "2014-08-30 15:00:00",
#                 "deep": 7,
#                 "deep_allowed": 7,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 1.27277,
#                 "npxGA": 0.964343,
#                 "npxGD": 0.308427,
#                 "ppda": {
#                     "att": 322,
#                     "def": 26
#                 },
#                 "ppda_allowed": {
#                     "att": 166,
#                     "def": 21
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 1,
#                 "wins": 1,
#                 "xG": 1.27277,
#                 "xGA": 0.964343,
#                 "xpts": 1.5890999999999997
#             },
#             {
#                 "date": "2014-09-14 16:00:00",
#                 "deep": 4,
#                 "deep_allowed": 9,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 4,
#                 "npxG": 0.563524,
#                 "npxGA": 2.20911,
#                 "npxGD": -1.6455859999999998,
#                 "ppda": {
#                     "att": 546,
#                     "def": 12
#                 },
#                 "ppda_allowed": {
#                     "att": 228,
#                     "def": 26
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.563524,
#                 "xGA": 2.20911,
#                 "xpts": 0.3136
#             },
#             {
#                 "date": "2014-09-20 12:45:00",
#                 "deep": 3,
#                 "deep_allowed": 6,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 2,
#                 "npxG": 1.05642,
#                 "npxGA": 1.45847,
#                 "npxGD": -0.40205,
#                 "ppda": {
#                     "att": 238,
#                     "def": 24
#                 },
#                 "ppda_allowed": {
#                     "att": 235,
#                     "def": 24
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 2,
#                 "wins": 0,
#                 "xG": 1.05642,
#                 "xGA": 1.45847,
#                 "xpts": 0.9737
#             },
#             {
#                 "date": "2014-09-27 15:00:00",
#                 "deep": 3,
#                 "deep_allowed": 8,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.456323,
#                 "npxGA": 2.34463,
#                 "npxGD": -1.888307,
#                 "ppda": {
#                     "att": 262,
#                     "def": 18
#                 },
#                 "ppda_allowed": {
#                     "att": 210,
#                     "def": 22
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 0.456323,
#                 "xGA": 2.34463,
#                 "xpts": 0.2299
#             },
#             {
#                 "date": "2014-10-05 16:15:00",
#                 "deep": 0,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.697342,
#                 "npxGA": 1.64038,
#                 "npxGD": -0.9430379999999999,
#                 "ppda": {
#                     "att": 234,
#                     "def": 24
#                 },
#                 "ppda_allowed": {
#                     "att": 273,
#                     "def": 22
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.697342,
#                 "xGA": 1.64038,
#                 "xpts": 0.5123
#             },
#             {
#                 "date": "2014-10-19 13:30:00",
#                 "deep": 8,
#                 "deep_allowed": 8,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 3,
#                 "npxG": 2.60852,
#                 "npxGA": 1.51813,
#                 "npxGD": 1.09039,
#                 "ppda": {
#                     "att": 258,
#                     "def": 34
#                 },
#                 "ppda_allowed": {
#                     "att": 126,
#                     "def": 20
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 2,
#                 "wins": 0,
#                 "xG": 2.60852,
#                 "xGA": 1.51813,
#                 "xpts": 2.1516
#             },
#             {
#                 "date": "2014-10-27 20:00:00",
#                 "deep": 3,
#                 "deep_allowed": 6,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.81667,
#                 "npxGA": 1.18709,
#                 "npxGD": -0.37041999999999997,
#                 "ppda": {
#                     "att": 340,
#                     "def": 25
#                 },
#                 "ppda_allowed": {
#                     "att": 123,
#                     "def": 22
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 0.81667,
#                 "xGA": 1.18709,
#                 "xpts": 0.9961
#             },
#             {
#                 "date": "2014-11-01 15:00:00",
#                 "deep": 3,
#                 "deep_allowed": 12,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.510067,
#                 "npxGA": 1.47586,
#                 "npxGD": -0.9657929999999999,
#                 "ppda": {
#                     "att": 300,
#                     "def": 23
#                 },
#                 "ppda_allowed": {
#                     "att": 176,
#                     "def": 32
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 0.510067,
#                 "xGA": 2.23703,
#                 "xpts": 0.24209999999999998
#             },
#             {
#                 "date": "2014-11-08 17:30:00",
#                 "deep": 4,
#                 "deep_allowed": 15,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 2,
#                 "npxG": 1.86489,
#                 "npxGA": 1.70189,
#                 "npxGD": 0.16300000000000003,
#                 "ppda": {
#                     "att": 271,
#                     "def": 28
#                 },
#                 "ppda_allowed": {
#                     "att": 175,
#                     "def": 21
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 2,
#                 "wins": 0,
#                 "xG": 1.86489,
#                 "xGA": 1.70189,
#                 "xpts": 1.5175999999999998
#             },
#             {
#                 "date": "2014-11-22 15:00:00",
#                 "deep": 5,
#                 "deep_allowed": 9,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 0.402285,
#                 "npxGA": 1.47871,
#                 "npxGD": -1.076425,
#                 "ppda": {
#                     "att": 184,
#                     "def": 26
#                 },
#                 "ppda_allowed": {
#                     "att": 149,
#                     "def": 34
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.402285,
#                 "xGA": 1.47871,
#                 "xpts": 0.47050000000000003
#             },
#             {
#                 "date": "2014-11-29 15:00:00",
#                 "deep": 7,
#                 "deep_allowed": 8,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 2,
#                 "npxG": 2.98194,
#                 "npxGA": 2.10013,
#                 "npxGD": 0.8818099999999998,
#                 "ppda": {
#                     "att": 105,
#                     "def": 13
#                 },
#                 "ppda_allowed": {
#                     "att": 175,
#                     "def": 29
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 3,
#                 "wins": 1,
#                 "xG": 2.98194,
#                 "xGA": 2.10013,
#                 "xpts": 1.9742000000000002
#             },
#             {
#                 "date": "2014-12-02 19:45:00",
#                 "deep": 4,
#                 "deep_allowed": 6,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.789519,
#                 "npxGA": 1.54207,
#                 "npxGD": -0.7525510000000001,
#                 "ppda": {
#                     "att": 335,
#                     "def": 28
#                 },
#                 "ppda_allowed": {
#                     "att": 186,
#                     "def": 24
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.789519,
#                 "xGA": 1.54207,
#                 "xpts": 0.7788
#             },
#             {
#                 "date": "2014-12-06 15:00:00",
#                 "deep": 11,
#                 "deep_allowed": 12,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 1.63744,
#                 "npxGA": 1.2646,
#                 "npxGD": 0.37284000000000006,
#                 "ppda": {
#                     "att": 157,
#                     "def": 14
#                 },
#                 "ppda_allowed": {
#                     "att": 161,
#                     "def": 25
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 1.63744,
#                 "xGA": 1.2646,
#                 "xpts": 1.654
#             },
#             {
#                 "date": "2014-12-15 20:00:00",
#                 "deep": 4,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 3,
#                 "npxG": 0.972265,
#                 "npxGA": 0.747708,
#                 "npxGD": 0.224557,
#                 "ppda": {
#                     "att": 286,
#                     "def": 28
#                 },
#                 "ppda_allowed": {
#                     "att": 232,
#                     "def": 29
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 0.972265,
#                 "xGA": 0.747708,
#                 "xpts": 1.5516999999999999
#             },
#             {
#                 "date": "2014-12-20 15:00:00",
#                 "deep": 4,
#                 "deep_allowed": 12,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 2,
#                 "npxG": 2.16747,
#                 "npxGA": 1.30117,
#                 "npxGD": 0.8662999999999998,
#                 "ppda": {
#                     "att": 184,
#                     "def": 22
#                 },
#                 "ppda_allowed": {
#                     "att": 157,
#                     "def": 17
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 3,
#                 "wins": 1,
#                 "xG": 2.92864,
#                 "xGA": 1.30117,
#                 "xpts": 2.5012
#             },
#             {
#                 "date": "2014-12-26 17:30:00",
#                 "deep": 7,
#                 "deep_allowed": 11,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.456385,
#                 "npxGA": 1.37771,
#                 "npxGD": -0.921325,
#                 "ppda": {
#                     "att": 304,
#                     "def": 35
#                 },
#                 "ppda_allowed": {
#                     "att": 221,
#                     "def": 18
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 1.21752,
#                 "xGA": 2.13888,
#                 "xpts": 0.6531
#             },
#             {
#                 "date": "2014-12-28 15:00:00",
#                 "deep": 4,
#                 "deep_allowed": 5,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.405679,
#                 "npxGA": 0.328577,
#                 "npxGD": 0.077102,
#                 "ppda": {
#                     "att": 112,
#                     "def": 24
#                 },
#                 "ppda_allowed": {
#                     "att": 177,
#                     "def": 22
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.405679,
#                 "xGA": 0.328577,
#                 "xpts": 1.3231
#             },
#             {
#                 "date": "2015-01-01 15:00:00",
#                 "deep": 9,
#                 "deep_allowed": 6,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 3.16214,
#                 "npxGA": 1.69725,
#                 "npxGD": 1.46489,
#                 "ppda": {
#                     "att": 293,
#                     "def": 37
#                 },
#                 "ppda_allowed": {
#                     "att": 155,
#                     "def": 15
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 3.16214,
#                 "xGA": 1.69725,
#                 "xpts": 2.3068999999999997
#             },
#             {
#                 "date": "2015-01-10 15:00:00",
#                 "deep": 7,
#                 "deep_allowed": 8,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.93438,
#                 "npxGA": 2.19126,
#                 "npxGD": -1.2568800000000002,
#                 "ppda": {
#                     "att": 138,
#                     "def": 12
#                 },
#                 "ppda_allowed": {
#                     "att": 170,
#                     "def": 27
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 1.69555,
#                 "xGA": 2.19126,
#                 "xpts": 1.0748
#             },
#             {
#                 "date": "2015-01-17 15:00:00",
#                 "deep": 6,
#                 "deep_allowed": 8,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.929623,
#                 "npxGA": 1.55645,
#                 "npxGD": -0.6268269999999999,
#                 "ppda": {
#                     "att": 262,
#                     "def": 25
#                 },
#                 "ppda_allowed": {
#                     "att": 172,
#                     "def": 30
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.929623,
#                 "xGA": 1.55645,
#                 "xpts": 0.8639
#             },
#             {
#                 "date": "2015-01-31 15:00:00",
#                 "deep": 4,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 3,
#                 "npxG": 1.11577,
#                 "npxGA": 0.782569,
#                 "npxGD": 0.33320099999999997,
#                 "ppda": {
#                     "att": 192,
#                     "def": 17
#                 },
#                 "ppda_allowed": {
#                     "att": 180,
#                     "def": 24
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 1.11577,
#                 "xGA": 0.782569,
#                 "xpts": 1.6808999999999998
#             },
#             {
#                 "date": "2015-02-07 15:00:00",
#                 "deep": 5,
#                 "deep_allowed": 10,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 1.03037,
#                 "npxGA": 0.963892,
#                 "npxGD": 0.06647800000000004,
#                 "ppda": {
#                     "att": 212,
#                     "def": 22
#                 },
#                 "ppda_allowed": {
#                     "att": 174,
#                     "def": 27
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.03037,
#                 "xGA": 0.963892,
#                 "xpts": 1.3948999999999998
#             },
#             {
#                 "date": "2015-02-10 19:45:00",
#                 "deep": 4,
#                 "deep_allowed": 4,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 1.26883,
#                 "npxGA": 1.80831,
#                 "npxGD": -0.5394800000000002,
#                 "ppda": {
#                     "att": 252,
#                     "def": 30
#                 },
#                 "ppda_allowed": {
#                     "att": 218,
#                     "def": 27
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 1.26883,
#                 "xGA": 1.80831,
#                 "xpts": 0.9351
#             },
#             {
#                 "date": "2015-02-21 15:00:00",
#                 "deep": 0,
#                 "deep_allowed": 6,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.190631,
#                 "npxGA": 1.09259,
#                 "npxGD": -0.901959,
#                 "ppda": {
#                     "att": 212,
#                     "def": 22
#                 },
#                 "ppda_allowed": {
#                     "att": 167,
#                     "def": 26
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 0.190631,
#                 "xGA": 1.09259,
#                 "xpts": 0.4784
#             },
#             {
#                 "date": "2015-03-04 19:45:00",
#                 "deep": 2,
#                 "deep_allowed": 15,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.318849,
#                 "npxGA": 2.1651,
#                 "npxGD": -1.8462509999999999,
#                 "ppda": {
#                     "att": 255,
#                     "def": 36
#                 },
#                 "ppda_allowed": {
#                     "att": 177,
#                     "def": 20
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 0.318849,
#                 "xGA": 2.1651,
#                 "xpts": 0.1923
#             },
#             {
#                 "date": "2015-03-07 15:00:00",
#                 "deep": 8,
#                 "deep_allowed": 4,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 1.49775,
#                 "npxGA": 2.62405,
#                 "npxGD": -1.1263,
#                 "ppda": {
#                     "att": 193,
#                     "def": 25
#                 },
#                 "ppda_allowed": {
#                     "att": 100,
#                     "def": 28
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 1.49775,
#                 "xGA": 2.62405,
#                 "xpts": 0.6722
#             },
#             {
#                 "date": "2015-03-14 12:45:00",
#                 "deep": 2,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 3,
#                 "npxG": 0.266048,
#                 "npxGA": 2.20095,
#                 "npxGD": -1.9349020000000001,
#                 "ppda": {
#                     "att": 110,
#                     "def": 23
#                 },
#                 "ppda_allowed": {
#                     "att": 191,
#                     "def": 21
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 0.266048,
#                 "xGA": 2.20095,
#                 "xpts": 0.1302
#             },
#             {
#                 "date": "2015-03-22 16:00:00",
#                 "deep": 18,
#                 "deep_allowed": 9,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 1.39318,
#                 "npxGA": 0.839996,
#                 "npxGD": 0.5531840000000001,
#                 "ppda": {
#                     "att": 156,
#                     "def": 31
#                 },
#                 "ppda_allowed": {
#                     "att": 151,
#                     "def": 27
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 1.39318,
#                 "xGA": 0.839996,
#                 "xpts": 1.8243
#             },
#             {
#                 "date": "2015-04-04 15:00:00",
#                 "deep": 5,
#                 "deep_allowed": 9,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 1.20939,
#                 "npxGA": 2.13361,
#                 "npxGD": -0.92422,
#                 "ppda": {
#                     "att": 222,
#                     "def": 21
#                 },
#                 "ppda_allowed": {
#                     "att": 182,
#                     "def": 16
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 4,
#                 "wins": 1,
#                 "xG": 1.20939,
#                 "xGA": 2.13361,
#                 "xpts": 0.7600999999999999
#             },
#             {
#                 "date": "2015-04-07 19:45:00",
#                 "deep": 3,
#                 "deep_allowed": 5,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 3,
#                 "npxG": 1.43061,
#                 "npxGA": 1.86698,
#                 "npxGD": -0.43637000000000015,
#                 "ppda": {
#                     "att": 195,
#                     "def": 22
#                 },
#                 "ppda_allowed": {
#                     "att": 117,
#                     "def": 18
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 3,
#                 "wins": 0,
#                 "xG": 1.43061,
#                 "xGA": 1.86698,
#                 "xpts": 1.0679
#             },
#             {
#                 "date": "2015-04-12 13:30:00",
#                 "deep": 2,
#                 "deep_allowed": 8,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 0.780982,
#                 "npxGA": 0.920984,
#                 "npxGD": -0.14000200000000007,
#                 "ppda": {
#                     "att": 212,
#                     "def": 30
#                 },
#                 "ppda_allowed": {
#                     "att": 116,
#                     "def": 17
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.780982,
#                 "xGA": 0.920984,
#                 "xpts": 1.1843
#             },
#             {
#                 "date": "2015-04-25 15:00:00",
#                 "deep": 15,
#                 "deep_allowed": 4,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 1.52026,
#                 "npxGA": 0.824309,
#                 "npxGD": 0.695951,
#                 "ppda": {
#                     "att": 98,
#                     "def": 20
#                 },
#                 "ppda_allowed": {
#                     "att": 105,
#                     "def": 22
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 2.28143,
#                 "xGA": 0.824309,
#                 "xpts": 2.4533
#             },
#             {
#                 "date": "2015-05-02 15:00:00",
#                 "deep": 1,
#                 "deep_allowed": 9,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.386314,
#                 "npxGA": 1.52628,
#                 "npxGD": -1.139966,
#                 "ppda": {
#                     "att": 236,
#                     "def": 23
#                 },
#                 "ppda_allowed": {
#                     "att": 113,
#                     "def": 21
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 0.386314,
#                 "xGA": 2.28745,
#                 "xpts": 0.1852
#             },
#             {
#                 "date": "2015-05-10 13:30:00",
#                 "deep": 1,
#                 "deep_allowed": 13,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 6,
#                 "npxG": 0.872314,
#                 "npxGA": 4.58986,
#                 "npxGD": -3.7175459999999996,
#                 "ppda": {
#                     "att": 268,
#                     "def": 21
#                 },
#                 "ppda_allowed": {
#                     "att": 169,
#                     "def": 25
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.872314,
#                 "xGA": 5.35103,
#                 "xpts": 0.009600000000000001
#             },
#             {
#                 "date": "2015-05-16 15:00:00",
#                 "deep": 2,
#                 "deep_allowed": 10,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 0.470106,
#                 "npxGA": 2.11207,
#                 "npxGD": -1.6419640000000002,
#                 "ppda": {
#                     "att": 118,
#                     "def": 40
#                 },
#                 "ppda_allowed": {
#                     "att": 124,
#                     "def": 31
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 0.470106,
#                 "xGA": 2.11207,
#                 "xpts": 0.312
#             },
#             {
#                 "date": "2015-05-24 15:00:00",
#                 "deep": 1,
#                 "deep_allowed": 3,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 5,
#                 "npxG": 1.26755,
#                 "npxGA": 2.17428,
#                 "npxGD": -0.90673,
#                 "ppda": {
#                     "att": 182,
#                     "def": 27
#                 },
#                 "ppda_allowed": {
#                     "att": 223,
#                     "def": 21
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 1.26755,
#                 "xGA": 2.17428,
#                 "xpts": 0.7654000000000001
#             }
#         ],
#         "id": "202",
#         "title": "Queens Park Rangers"
#     },
#     "71": {
#         "history": [
#             {
#                 "date": "2014-08-16 15:00:00",
#                 "deep": 4,
#                 "deep_allowed": 3,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.909774,
#                 "npxGA": 0.423368,
#                 "npxGD": 0.48640599999999995,
#                 "ppda": {
#                     "att": 323,
#                     "def": 23
#                 },
#                 "ppda_allowed": {
#                     "att": 132,
#                     "def": 32
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 1,
#                 "wins": 1,
#                 "xG": 0.909774,
#                 "xGA": 0.423368,
#                 "xpts": 1.8321999999999998
#             },
#             {
#                 "date": "2014-08-23 12:45:00",
#                 "deep": 4,
#                 "deep_allowed": 7,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.507525,
#                 "npxGA": 0.699295,
#                 "npxGD": -0.19177,
#                 "ppda": {
#                     "att": 326,
#                     "def": 21
#                 },
#                 "ppda_allowed": {
#                     "att": 180,
#                     "def": 21
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.507525,
#                 "xGA": 0.699295,
#                 "xpts": 1.1057
#             },
#             {
#                 "date": "2014-08-31 13:30:00",
#                 "deep": 6,
#                 "deep_allowed": 7,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 0.639316,
#                 "npxGA": 0.28888,
#                 "npxGD": 0.35043599999999997,
#                 "ppda": {
#                     "att": 366,
#                     "def": 13
#                 },
#                 "ppda_allowed": {
#                     "att": 278,
#                     "def": 24
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 0.639316,
#                 "xGA": 0.28888,
#                 "xpts": 1.6075
#             },
#             {
#                 "date": "2014-09-13 17:30:00",
#                 "deep": 1,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.701676,
#                 "npxGA": 0.728097,
#                 "npxGD": -0.026421000000000028,
#                 "ppda": {
#                     "att": 486,
#                     "def": 9
#                 },
#                 "ppda_allowed": {
#                     "att": 91,
#                     "def": 14
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 1,
#                 "wins": 1,
#                 "xG": 0.701676,
#                 "xGA": 0.728097,
#                 "xpts": 1.3252
#             },
#             {
#                 "date": "2014-09-20 15:00:00",
#                 "deep": 0,
#                 "deep_allowed": 7,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 3,
#                 "npxG": 0.649013,
#                 "npxGA": 1.36224,
#                 "npxGD": -0.7132269999999999,
#                 "ppda": {
#                     "att": 531,
#                     "def": 12
#                 },
#                 "ppda_allowed": {
#                     "att": 170,
#                     "def": 22
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.649013,
#                 "xGA": 1.36224,
#                 "xpts": 0.6912
#             },
#             {
#                 "date": "2014-09-27 15:00:00",
#                 "deep": 2,
#                 "deep_allowed": 6,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 3,
#                 "npxG": 0.228896,
#                 "npxGA": 3.14218,
#                 "npxGD": -2.913284,
#                 "ppda": {
#                     "att": 395,
#                     "def": 8
#                 },
#                 "ppda_allowed": {
#                     "att": 273,
#                     "def": 15
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.228896,
#                 "xGA": 3.14218,
#                 "xpts": 0.0219
#             },
#             {
#                 "date": "2014-10-04 17:30:00",
#                 "deep": 1,
#                 "deep_allowed": 12,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.690283,
#                 "npxGA": 2.30634,
#                 "npxGD": -1.616057,
#                 "ppda": {
#                     "att": 490,
#                     "def": 19
#                 },
#                 "ppda_allowed": {
#                     "att": 202,
#                     "def": 26
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.690283,
#                 "xGA": 2.30634,
#                 "xpts": 0.39339999999999997
#             },
#             {
#                 "date": "2014-10-18 15:00:00",
#                 "deep": 6,
#                 "deep_allowed": 7,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 3,
#                 "npxG": 0.37205,
#                 "npxGA": 1.67016,
#                 "npxGD": -1.29811,
#                 "ppda": {
#                     "att": 414,
#                     "def": 24
#                 },
#                 "ppda_allowed": {
#                     "att": 193,
#                     "def": 12
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.37205,
#                 "xGA": 1.67016,
#                 "xpts": 0.34140000000000004
#             },
#             {
#                 "date": "2014-10-27 20:00:00",
#                 "deep": 6,
#                 "deep_allowed": 3,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 1.18709,
#                 "npxGA": 0.81667,
#                 "npxGD": 0.37041999999999997,
#                 "ppda": {
#                     "att": 123,
#                     "def": 22
#                 },
#                 "ppda_allowed": {
#                     "att": 340,
#                     "def": 25
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.18709,
#                 "xGA": 0.81667,
#                 "xpts": 1.6813
#             },
#             {
#                 "date": "2014-11-02 16:00:00",
#                 "deep": 3,
#                 "deep_allowed": 11,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.872267,
#                 "npxGA": 2.54173,
#                 "npxGD": -1.669463,
#                 "ppda": {
#                     "att": 273,
#                     "def": 19
#                 },
#                 "ppda_allowed": {
#                     "att": 145,
#                     "def": 18
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 0.872267,
#                 "xGA": 2.54173,
#                 "xpts": 0.3639
#             },
#             {
#                 "date": "2014-11-08 15:00:00",
#                 "deep": 2,
#                 "deep_allowed": 15,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.560875,
#                 "npxGA": 1.47873,
#                 "npxGD": -0.9178550000000001,
#                 "ppda": {
#                     "att": 241,
#                     "def": 17
#                 },
#                 "ppda_allowed": {
#                     "att": 158,
#                     "def": 21
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.560875,
#                 "xGA": 1.47873,
#                 "xpts": 0.6379
#             },
#             {
#                 "date": "2014-11-24 20:00:00",
#                 "deep": 3,
#                 "deep_allowed": 14,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 1.13228,
#                 "npxGA": 0.863156,
#                 "npxGD": 0.2691239999999999,
#                 "ppda": {
#                     "att": 292,
#                     "def": 14
#                 },
#                 "ppda_allowed": {
#                     "att": 124,
#                     "def": 20
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 1.13228,
#                 "xGA": 0.863156,
#                 "xpts": 1.6318000000000001
#             },
#             {
#                 "date": "2014-11-29 15:00:00",
#                 "deep": 11,
#                 "deep_allowed": 7,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 1.0873,
#                 "npxGA": 1.54463,
#                 "npxGD": -0.45733,
#                 "ppda": {
#                     "att": 254,
#                     "def": 11
#                 },
#                 "ppda_allowed": {
#                     "att": 263,
#                     "def": 25
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 1.0873,
#                 "xGA": 2.3058,
#                 "xpts": 0.5442
#             },
#             {
#                 "date": "2014-12-02 20:00:00",
#                 "deep": 2,
#                 "deep_allowed": 6,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.192439,
#                 "npxGA": 0.801741,
#                 "npxGD": -0.609302,
#                 "ppda": {
#                     "att": 119,
#                     "def": 18
#                 },
#                 "ppda_allowed": {
#                     "att": 223,
#                     "def": 37
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 1,
#                 "wins": 1,
#                 "xG": 0.192439,
#                 "xGA": 0.801741,
#                 "xpts": 0.6592
#             },
#             {
#                 "date": "2014-12-07 16:00:00",
#                 "deep": 7,
#                 "deep_allowed": 6,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 1.97697,
#                 "npxGA": 1.0083,
#                 "npxGD": 0.9686699999999999,
#                 "ppda": {
#                     "att": 135,
#                     "def": 21
#                 },
#                 "ppda_allowed": {
#                     "att": 327,
#                     "def": 35
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 1.97697,
#                 "xGA": 1.0083,
#                 "xpts": 2.0575
#             },
#             {
#                 "date": "2014-12-13 15:00:00",
#                 "deep": 4,
#                 "deep_allowed": 3,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 0.266303,
#                 "npxGA": 1.4373,
#                 "npxGD": -1.170997,
#                 "ppda": {
#                     "att": 202,
#                     "def": 13
#                 },
#                 "ppda_allowed": {
#                     "att": 280,
#                     "def": 34
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.266303,
#                 "xGA": 1.4373,
#                 "xpts": 0.3204
#             },
#             {
#                 "date": "2014-12-20 15:00:00",
#                 "deep": 3,
#                 "deep_allowed": 7,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 0.575806,
#                 "npxGA": 1.06851,
#                 "npxGD": -0.49270400000000003,
#                 "ppda": {
#                     "att": 301,
#                     "def": 13
#                 },
#                 "ppda_allowed": {
#                     "att": 202,
#                     "def": 19
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 0.575806,
#                 "xGA": 1.06851,
#                 "xpts": 0.8913
#             },
#             {
#                 "date": "2014-12-26 15:00:00",
#                 "deep": 10,
#                 "deep_allowed": 6,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 1.41578,
#                 "npxGA": 0.601468,
#                 "npxGD": 0.814312,
#                 "ppda": {
#                     "att": 278,
#                     "def": 19
#                 },
#                 "ppda_allowed": {
#                     "att": 376,
#                     "def": 28
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.41578,
#                 "xGA": 0.601468,
#                 "xpts": 2.0369
#             },
#             {
#                 "date": "2014-12-28 15:00:00",
#                 "deep": 7,
#                 "deep_allowed": 6,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.650993,
#                 "npxGA": 0.845626,
#                 "npxGD": -0.19463299999999994,
#                 "ppda": {
#                     "att": 270,
#                     "def": 15
#                 },
#                 "ppda_allowed": {
#                     "att": 262,
#                     "def": 20
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.650993,
#                 "xGA": 0.845626,
#                 "xpts": 1.1384999999999998
#             },
#             {
#                 "date": "2015-01-01 15:00:00",
#                 "deep": 7,
#                 "deep_allowed": 4,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 1.38709,
#                 "npxGA": 0.575995,
#                 "npxGD": 0.8110949999999999,
#                 "ppda": {
#                     "att": 134,
#                     "def": 27
#                 },
#                 "ppda_allowed": {
#                     "att": 373,
#                     "def": 24
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.38709,
#                 "xGA": 0.575995,
#                 "xpts": 2.0644
#             },
#             {
#                 "date": "2015-01-10 15:00:00",
#                 "deep": 8,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 0.606149,
#                 "npxGA": 2.36522,
#                 "npxGD": -1.7590709999999998,
#                 "ppda": {
#                     "att": 120,
#                     "def": 19
#                 },
#                 "ppda_allowed": {
#                     "att": 304,
#                     "def": 44
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.606149,
#                 "xGA": 2.36522,
#                 "xpts": 0.2633
#             },
#             {
#                 "date": "2015-01-17 15:00:00",
#                 "deep": 14,
#                 "deep_allowed": 7,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.845309,
#                 "npxGA": 1.54424,
#                 "npxGD": -0.6989310000000001,
#                 "ppda": {
#                     "att": 275,
#                     "def": 25
#                 },
#                 "ppda_allowed": {
#                     "att": 209,
#                     "def": 28
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.845309,
#                 "xGA": 1.54424,
#                 "xpts": 0.7783
#             },
#             {
#                 "date": "2015-02-01 13:30:00",
#                 "deep": 6,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
# ...
#             },
#             {
#                 "date": "2014-12-28 15:00:00",
#                 "deep": 4,
#                 "deep_allowed": 17,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 2,
#                 "npxG": 0.962215,
#                 "npxGA": 1.38586,
#                 "npxGD": -0.42364500000000005,
#                 "ppda": {
#                     "att": 263,
#                     "def": 17
#                 },
#                 "ppda_allowed": {
#                     "att": 176,
#                     "def": 24
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 2,
#                 "wins": 0,
#                 "xG": 0.962215,
#                 "xGA": 1.38586,
#                 "xpts": 1.0237
#             },
#             {
#                 "date": "2015-01-01 15:00:00",
#                 "deep": 2,
#                 "deep_allowed": 3,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 3,
#                 "npxG": 1.65582,
#                 "npxGA": 1.24639,
#                 "npxGD": 0.40942999999999996,
#                 "ppda": {
#                     "att": 218,
#                     "def": 33
#                 },
#                 "ppda_allowed": {
#                     "att": 227,
#                     "def": 18
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 3,
#                 "wins": 0,
#                 "xG": 1.65582,
#                 "xGA": 1.24639,
#                 "xpts": 1.6915999999999998
#             },
#             {
#                 "date": "2015-01-10 15:00:00",
#                 "deep": 8,
#                 "deep_allowed": 7,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 2.19126,
#                 "npxGA": 0.93438,
#                 "npxGD": 1.2568800000000002,
#                 "ppda": {
#                     "att": 170,
#                     "def": 27
#                 },
#                 "ppda_allowed": {
#                     "att": 138,
#                     "def": 12
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 2.19126,
#                 "xGA": 1.69555,
#                 "xpts": 1.6804999999999999
#             },
#             {
#                 "date": "2015-01-17 15:00:00",
#                 "deep": 7,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 3,
#                 "npxG": 1.08428,
#                 "npxGA": 0.528431,
#                 "npxGD": 0.5558489999999999,
#                 "ppda": {
#                     "att": 173,
#                     "def": 28
#                 },
#                 "ppda_allowed": {
#                     "att": 170,
#                     "def": 23
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 2,
#                 "wins": 0,
#                 "xG": 1.08428,
#                 "xGA": 0.528431,
#                 "xpts": 1.8602
#             },
#             {
#                 "date": "2015-01-31 15:00:00",
#                 "deep": 7,
#                 "deep_allowed": 6,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 1.34786,
#                 "npxGA": 1.89994,
#                 "npxGD": -0.5520799999999999,
#                 "ppda": {
#                     "att": 226,
#                     "def": 36
#                 },
#                 "ppda_allowed": {
#                     "att": 218,
#                     "def": 17
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.34786,
#                 "xGA": 1.89994,
#                 "xpts": 0.859
#             },
#             {
#                 "date": "2015-02-08 12:00:00",
#                 "deep": 7,
#                 "deep_allowed": 0,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 2,
#                 "npxG": 1.09795,
#                 "npxGA": 2.55442,
#                 "npxGD": -1.45647,
#                 "ppda": {
#                     "att": 176,
#                     "def": 18
#                 },
#                 "ppda_allowed": {
#                     "att": 282,
#                     "def": 21
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 2,
#                 "wins": 0,
#                 "xG": 1.09795,
#                 "xGA": 2.55442,
#                 "xpts": 0.4696
#             },
#             {
#                 "date": "2015-02-11 19:45:00",
#                 "deep": 10,
#                 "deep_allowed": 6,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 3,
#                 "npxG": 1.85067,
#                 "npxGA": 0.859992,
#                 "npxGD": 0.9906780000000001,
#                 "ppda": {
#                     "att": 312,
#                     "def": 31
#                 },
#                 "ppda_allowed": {
#                     "att": 205,
#                     "def": 24
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 1.85067,
#                 "xGA": 1.62116,
#                 "xpts": 1.5408
#             },
#             {
#                 "date": "2015-02-21 15:00:00",
#                 "deep": 2,
#                 "deep_allowed": 11,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 0.513251,
#                 "npxGA": 1.53973,
#                 "npxGD": -1.0264790000000001,
#                 "ppda": {
#                     "att": 279,
#                     "def": 27
#                 },
#                 "ppda_allowed": {
#                     "att": 203,
#                     "def": 23
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 0.513251,
#                 "xGA": 1.53973,
#                 "xpts": 0.486
#             },
#             {
#                 "date": "2015-02-28 15:00:00",
#                 "deep": 5,
#                 "deep_allowed": 4,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 0.898885,
#                 "npxGA": 1.41451,
#                 "npxGD": -0.5156249999999999,
#                 "ppda": {
#                     "att": 233,
#                     "def": 25
#                 },
#                 "ppda_allowed": {
#                     "att": 188,
#                     "def": 17
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.898885,
#                 "xGA": 1.41451,
#                 "xpts": 0.8543000000000001
#             },
#             {
#                 "date": "2015-03-04 20:00:00",
#                 "deep": 3,
#                 "deep_allowed": 7,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.319239,
#                 "npxGA": 1.30453,
#                 "npxGD": -0.9852909999999999,
#                 "ppda": {
#                     "att": 398,
#                     "def": 36
#                 },
#                 "ppda_allowed": {
#                     "att": 219,
#                     "def": 17
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.319239,
#                 "xGA": 1.30453,
#                 "xpts": 0.5109
#             },
#             {
#                 "date": "2015-03-14 17:30:00",
#                 "deep": 3,
#                 "deep_allowed": 13,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.242058,
#                 "npxGA": 1.2576,
#                 "npxGD": -1.015542,
#                 "ppda": {
#                     "att": 375,
#                     "def": 19
#                 },
#                 "ppda_allowed": {
#                     "att": 144,
#                     "def": 29
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 1,
#                 "wins": 1,
#                 "xG": 0.242058,
#                 "xGA": 1.2576,
#                 "xpts": 0.4818
#             },
#             {
#                 "date": "2015-03-21 15:00:00",
#                 "deep": 10,
#                 "deep_allowed": 9,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 1.05022,
#                 "npxGA": 1.92097,
#                 "npxGD": -0.8707500000000001,
#                 "ppda": {
#                     "att": 326,
#                     "def": 19
#                 },
#                 "ppda_allowed": {
#                     "att": 187,
#                     "def": 15
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.05022,
#                 "xGA": 1.92097,
#                 "xpts": 0.7578
#             },
#             {
#                 "date": "2015-04-05 13:30:00",
#                 "deep": 4,
#                 "deep_allowed": 4,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 1.51355,
#                 "npxGA": 0.377376,
#                 "npxGD": 1.136174,
#                 "ppda": {
#                     "att": 312,
#                     "def": 29
#                 },
#                 "ppda_allowed": {
#                     "att": 154,
#                     "def": 13
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.51355,
#                 "xGA": 0.377376,
#                 "xpts": 2.3229
#             },
#             {
#                 "date": "2015-04-11 17:30:00",
#                 "deep": 6,
#                 "deep_allowed": 7,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 0.65718,
#                 "npxGA": 1.21096,
#                 "npxGD": -0.55378,
#                 "ppda": {
#                     "att": 341,
#                     "def": 40
#                 },
#                 "ppda_allowed": {
#                     "att": 124,
#                     "def": 23
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.65718,
#                 "xGA": 1.21096,
#                 "xpts": 0.8343
#             },
#             {
#                 "date": "2015-04-18 15:00:00",
#                 "deep": 5,
#                 "deep_allowed": 14,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 1.06159,
#                 "npxGA": 1.59997,
#                 "npxGD": -0.5383799999999999,
#                 "ppda": {
#                     "att": 296,
#                     "def": 21
#                 },
#                 "ppda_allowed": {
#                     "att": 111,
#                     "def": 18
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.06159,
#                 "xGA": 2.36114,
#                 "xpts": 0.5037
#             },
#             {
#                 "date": "2015-04-25 15:00:00",
#                 "deep": 4,
#                 "deep_allowed": 1,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 1.22858,
#                 "npxGA": 1.21926,
#                 "npxGD": 0.009319999999999995,
#                 "ppda": {
#                     "att": 93,
#                     "def": 23
#                 },
#                 "ppda_allowed": {
#                     "att": 180,
#                     "def": 25
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.98975,
#                 "xGA": 1.21926,
#                 "xpts": 2.0483000000000002
#             },
#             {
#                 "date": "2015-05-02 15:00:00",
#                 "deep": 8,
#                 "deep_allowed": 10,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 0.758485,
#                 "npxGA": 2.47808,
#                 "npxGD": -1.719595,
#                 "ppda": {
#                     "att": 228,
#                     "def": 21
#                 },
#                 "ppda_allowed": {
#                     "att": 167,
#                     "def": 17
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.758485,
#                 "xGA": 3.23925,
#                 "xpts": 0.17220000000000002
#             },
#             {
#                 "date": "2015-05-09 15:00:00",
#                 "deep": 8,
#                 "deep_allowed": 6,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 1.21303,
#                 "npxGA": 1.12811,
#                 "npxGD": 0.0849200000000001,
#                 "ppda": {
#                     "att": 214,
#                     "def": 18
#                 },
#                 "ppda_allowed": {
#                     "att": 198,
#                     "def": 24
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 1,
#                 "wins": 1,
#                 "xG": 1.21303,
#                 "xGA": 1.12811,
#                 "xpts": 1.4367
#             },
#             {
#                 "date": "2015-05-16 15:00:00",
#                 "deep": 5,
#                 "deep_allowed": 3,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.909845,
#                 "npxGA": 1.76276,
#                 "npxGD": -0.8529150000000001,
#                 "ppda": {
#                     "att": 259,
#                     "def": 13
#                 },
#                 "ppda_allowed": {
#                     "att": 169,
#                     "def": 23
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.909845,
#                 "xGA": 1.76276,
#                 "xpts": 0.6360999999999999
#             },
#             {
#                 "date": "2015-05-24 15:00:00",
#                 "deep": 6,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.66113,
#                 "npxGA": 0.654751,
#                 "npxGD": 0.0063790000000000235,
#                 "ppda": {
#                     "att": 275,
#                     "def": 14
#                 },
#                 "ppda_allowed": {
#                     "att": 162,
#                     "def": 15
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 1,
#                 "wins": 1,
#                 "xG": 0.66113,
#                 "xGA": 0.654751,
#                 "xpts": 1.3295
#             }
#         ],
#         "id": "92",
#         "title": "Burnley"
#     }
# }

# %%
data = json.loads(json_data)
print(data.keys())
# print('-' * 100)
# print(data['71'].keys())
# print('-' * 100)
# print(data['71']['id'])
# print('-' * 100)
# print(data['71']['title'])
# print('-' * 100)
# print(data['71']['history'])
# Out:
# dict_keys(['71', '72', '74', '75', '76', '77', '78', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '91', '92', '202'])

# %% [markdown]
# **making a dictionary composed opf team ID and team titles**

# %%
teams ={}

for id in data.keys():
    teams[id] = data[id]['title']

# %%
teams
# Out:
# {'71': 'Aston Villa',
#  '72': 'Everton',
#  '74': 'Southampton',
#  '75': 'Leicester',
#  '76': 'West Bromwich Albion',
#  '77': 'Sunderland',
#  '78': 'Crystal Palace',
#  '80': 'Chelsea',
#  '81': 'West Ham',
#  '82': 'Tottenham',
#  '83': 'Arsenal',
#  '84': 'Swansea',
#  '85': 'Stoke',
#  '86': 'Newcastle United',
#  '87': 'Liverpool',
#  '88': 'Manchester City',
#  '89': 'Manchester United',
#  '91': 'Hull',
#  '92': 'Burnley',
#  '202': 'Queens Park Rangers'}

# %%
columns = []
values = []
for id in data.keys():
    columns = list(data[id]['history'][0].keys())
    values = list(data[id]['history'][0].values())
    break

print(columns)
# print(values)
# Out:
# ['h_a', 'xG', 'xGA', 'npxG', 'npxGA', 'ppda', 'ppda_allowed', 'deep', 'deep_allowed', 'scored', 'missed', 'xpts', 'result', 'date', 'wins', 'draws', 'loses', 'pts', 'npxGD']

# %%
# QPR_data = []

# for i in data['202']['history']:
#     QPR_data.append(list(i.values()))
    
# print(QPR_data)

# %%
# s = json.dumps(data, indent = 2, sort_keys =True)
# print(s)

# %%
# print(teams.items())
# type(data['202']['history'][0].values())

# %%
all_team_dicts = {}

for id, team in teams.items():
    teams_data = []
    for i in data[id]['history']:
        teams_data.append(list(i.values()))
        
    df = pd.DataFrame(teams_data, columns = columns)
    all_team_dicts[team] = df
    print('Added data for {}.'.format(team))
# Out:
# Added data for Aston Villa.
# Added data for Everton.
# Added data for Southampton.
# Added data for Leicester.
# Added data for West Bromwich Albion.
# Added data for Sunderland.
# Added data for Crystal Palace.
# Added data for Chelsea.
# Added data for West Ham.
# Added data for Tottenham.
# Added data for Arsenal.
# Added data for Swansea.
# Added data for Stoke.
# Added data for Newcastle United.
# Added data for Liverpool.
# Added data for Manchester City.
# Added data for Manchester United.
# Added data for Hull.
# Added data for Burnley.
# Added data for Queens Park Rangers.

# %%
all_team_dicts['Manchester United']
# Out:
#    h_a        xG       xGA      npxG     npxGA                     ppda  \
# 0    h  1.166350  0.278076  1.166350  0.278076  {'att': 253, 'def': 25}
# 1    a  0.941557  0.666489  0.941557  0.666489  {'att': 297, 'def': 27}
# 2    a  0.467281  0.513746  0.467281  0.513746  {'att': 150, 'def': 21}
# 3    h  2.209110  0.563524  2.209110  0.563524  {'att': 228, 'def': 26}
# 4    a  1.711910  2.542200  1.711910  1.019860  {'att': 174, 'def': 26}
# 5    h  0.520246  1.274520  0.520246  1.274520  {'att': 189, 'def': 13}
# 6    h  1.623900  2.135580  1.623900  1.374410  {'att': 268, 'def': 36}
# 7    a  0.934042  0.616620  0.934042  0.616620  {'att': 214, 'def': 27}
# 8    h  1.840740  0.989916  1.840740  0.989916  {'att': 245, 'def': 18}
# 9    a  0.727924  2.567230  0.727924  2.567230  {'att': 253, 'def': 19}
# 10   h  0.956776  0.400837  0.956776  0.400837  {'att': 127, 'def': 17}
# 11   a  1.279100  2.001930  1.279100  2.001930  {'att': 258, 'def': 18}
# 12   h  1.768850  0.230407  1.768850  0.230407  {'att': 151, 'def': 25}
# 13   h  1.911040  1.290920  1.911040  1.290920  {'att': 204, 'def': 27}
# 14   a  0.799261  1.828700  0.799261  1.828700  {'att': 290, 'def': 16}
# 15   h  1.795430  1.871140  1.795430  1.871140  {'att': 244, 'def': 41}
# 16   a  1.068510  0.575806  1.068510  0.575806  {'att': 202, 'def': 19}
# 17   h  1.861470  1.031510  1.861470  0.270375  {'att': 207, 'def': 27}
# 18   a  2.261300  0.888000  2.261300  0.888000  {'att': 148, 'def': 30}
# 19   a  0.932262  1.408200  0.932262  1.408200  {'att': 101, 'def': 23}
# 20   h  1.192280  1.157060  1.192280  1.157060  {'att': 192, 'def': 20}
# 21   a  1.556450  0.929623  1.556450  0.929623  {'att': 172, 'def': 30}
# 22   h  1.736900  0.380882  1.736900  0.380882   {'att': 98, 'def': 21}
# 23   a  1.213440  0.865180  1.213440  0.865180  {'att': 129, 'def': 22}
# 24   h  1.621160  1.850670  0.859992  1.850670  {'att': 205, 'def': 24}
# 25   a  1.471710  1.042180  1.471710  1.042180  {'att': 171, 'def': 34}
# 26   h  3.035340  0.272806  2.274170  0.272806  {'att': 122, 'def': 21}
# 27   a  1.688650  1.192460  1.688650  1.192460   {'att': 99, 'def': 25}
# 28   h  1.027810  0.206431  1.027810  0.206431  {'att': 287, 'def': 36}
# 29   a  1.226320  0.557648  0.465151  0.557648  {'att': 217, 'def': 45}
# 30   h  1.983600  0.311787  1.983600  0.311787  {'att': 117, 'def': 33}
# 31   h  2.660170  1.758440  2.660170  1.758440  {'att': 179, 'def': 26}
# 32   a  0.744613  1.149300  0.744613  1.149300  {'att': 151, 'def': 29}
# 33   a  0.750462  1.079220  0.750462  1.079220  {'att': 163, 'def': 29}
# 34   h  2.108410  0.317533  1.347240  0.317533   {'att': 69, 'def': 27}
# 35   a  2.297750  1.043440  1.536580  1.043440  {'att': 106, 'def': 20}
# 36   h  0.715214  1.068140  0.715214  1.068140  {'att': 229, 'def': 45}
# 37   a  0.399522  0.984196  0.399522  0.984196  {'att': 163, 'def': 24}
#
#                ppda_allowed  deep  deep_allowed  scored  missed    xpts  \
# 0   {'att': 341, 'def': 19}     8             2       1       2  2.2359
# 1   {'att': 267, 'def': 21}     2             4       1       1  1.6740
# 2   {'att': 305, 'def': 27}    11             2       0       0  1.2096
# 3   {'att': 546, 'def': 12}     9             4       4       0  2.5363
# 4   {'att': 285, 'def': 23}     7             6       3       5  0.8067
# 5   {'att': 315, 'def': 21}     5            10       2       1  0.6965
# 6   {'att': 269, 'def': 20}     4             7       2       1  0.9917
# 7   {'att': 286, 'def': 16}     8             3       2       2  1.5720
# 8   {'att': 254, 'def': 18}     7             8       1       1  2.0214
# 9   {'att': 258, 'def': 35}     5            14       0       1  0.3017
# 10  {'att': 390, 'def': 15}     3             3       1       0  1.8430
# 11  {'att': 137, 'def': 23}     2            12       2       1  0.8730
# 12  {'att': 508, 'def': 26}     8             1       3       0  2.7343
# 13  {'att': 382, 'def': 18}    10             2       2       1  1.8367
# 14  {'att': 255, 'def': 38}     2             9       2       1  0.5970
# 15  {'att': 308, 'def': 23}     5            10       3       0  1.3549
# 16  {'att': 301, 'def': 13}     7             3       1       1  1.7778
# 17  {'att': 356, 'def': 21}    10             1       3       1  2.0775
# 18  {'att': 186, 'def': 25}     6             1       0       0  2.4352
# 19  {'att': 281, 'def': 16}     9             5       1       1  0.9356
# 20  {'att': 280, 'def': 14}     4             5       0       1  1.3914
# 21  {'att': 262, 'def': 25}     8             6       2       0  1.8800
# 22  {'att': 416, 'def': 27}    10             5       3       1  2.5154
# 23  {'att': 189, 'def': 18}    10             3       1       1  1.6447
# 24  {'att': 312, 'def': 31}     6            10       3       1  1.1847
# 25  {'att': 291, 'def': 14}    10             6       1       2  1.7129
# 26  {'att': 265, 'def': 19}    10             0       2       0  2.9045
# 27  {'att': 277, 'def': 23}     7             3       1       0  1.7829
# 28  {'att': 268, 'def': 29}     5             2       3       0  2.1402
# 29  {'att': 283, 'def': 22}     3             7       2       1  2.0502
# 30  {'att': 351, 'def': 14}    11             3       3       1  2.6149
# 31  {'att': 320, 'def': 30}     3             7       4       2  2.0276
# 32  {'att': 394, 'def': 27}     8             5       0       1  0.9084
# 33  {'att': 263, 'def': 16}     8             2       0       3  1.0058
# 34  {'att': 298, 'def': 14}    19             2       0       1  2.6858
# 35  {'att': 252, 'def': 20}     7            13       2       1  2.3349
# 36  {'att': 271, 'def': 19}     7             6       1       1  0.9643
# 37  {'att': 294, 'def': 21}     3             2       0       0  0.7733
#
#    result                 date  wins  draws  loses  pts     npxGD
# 0       l  2014-08-16 12:45:00     0      0      1    0  0.888274
# 1       d  2014-08-24 16:00:00     0      1      0    1  0.275068
# 2       d  2014-08-30 12:45:00     0      1      0    1 -0.046465
# 3       w  2014-09-14 16:00:00     1      0      0    3  1.645586
# 4       l  2014-09-21 13:30:00     0      0      1    0  0.692050
# 5       w  2014-09-27 15:00:00     1      0      0    3 -0.754274
# 6       w  2014-10-05 12:00:00     1      0      0    3  0.249490
# 7       d  2014-10-20 20:00:00     0      1      0    1  0.317422
# 8       d  2014-10-26 16:00:00     0      1      0    1  0.850824
# 9       l  2014-11-02 13:30:00     0      0      1    0 -1.839306
# 10      w  2014-11-08 15:00:00     1      0      0    3  0.555939
# 11      w  2014-11-22 17:30:00     1      0      0    3 -0.722830
# 12      w  2014-11-29 15:00:00     1      0      0    3  1.538443
# 13      w  2014-12-02 19:45:00     1      0      0    3  0.620120
# 14      w  2014-12-08 20:00:00     1      0      0    3 -1.029439
# 15      w  2014-12-14 13:30:00     1      0      0    3 -0.075710
# 16      d  2014-12-20 15:00:00     0      1      0    1  0.492704
# 17      w  2014-12-26 15:00:00     1      0      0    3  1.591095
# 18      d  2014-12-28 12:00:00     0      1      0    1  1.373300
# 19      d  2015-01-01 12:45:00     0      1      0    1 -0.475938
# 20      l  2015-01-11 16:00:00     0      0      1    0  0.035220
# 21      w  2015-01-17 15:00:00     1      0      0    3  0.626827
# 22      w  2015-01-31 15:00:00     1      0      0    3  1.356018
# 23      d  2015-02-08 16:15:00     0      1      0    1  0.348260
# 24      w  2015-02-11 19:45:00     1      0      0    3 -0.990678
# 25      l  2015-02-21 15:00:00     0      0      1    0  0.429530
# 26      w  2015-02-28 15:00:00     1      0      0    3  2.001364
# 27      w  2015-03-04 19:45:00     1      0      0    3  0.496190
# 28      w  2015-03-15 16:00:00     1      0      0    3  0.821379
# 29      w  2015-03-22 13:30:00     1      0      0    3 -0.092497
# 30      w  2015-04-04 15:00:00     1      0      0    3  1.671813
# 31      w  2015-04-12 16:00:00     1      0      0    3  0.901730
# 32      l  2015-04-18 17:30:00     0      0      1    0 -0.404687
# 33      l  2015-04-26 13:30:00     0      0      1    0 -0.328758
# 34      l  2015-05-02 17:30:00     0      0      1    0  1.029707
# 35      w  2015-05-09 17:30:00     1      0      0    3  0.493140
# 36      d  2015-05-17 16:00:00     0      1      0    1 -0.352926
# 37      d  2015-05-24 15:00:00     0      1      0    1 -0.584674

# %%
import os

for team, df in all_team_dicts.items():
    df['ppda_coef'] =  df['ppda'].apply(lambda x : x['att']/x['def'] if x['def'] != 0 else 0)
    df['oppda_coef'] = df['ppda_allowed'].apply(lambda x : x['att']/x['def'] if x['def'] != 0 else 0)
    df['GW'] = range(1,len(df) + 1)
    df = df[['GW','date','result','h_a','xG','scored', 'xGA', 'missed', 'xpts', 'pts', 'npxG', 'npxGA','ppda', 'ppda_allowed', 'ppda_coef', 'oppda_coef', 'deep',
       'deep_allowed', 'npxGD']]
    df.rename(columns = {'missed': 'conceded',
                        'h_a': 'Home/Away'}, inplace = True)
    outname = '{}_{}_season data.csv'.format(team, season_names[0])
    outdir = r'C:\Users\Asus\PycharmProjects\Understat Data Scraper\Data\Team_Data\{}_season'.format(season_names[0])
    if not os.path.exists(outdir):
        os.mkdir(outdir)
    fullname = os.path.join(outdir, outname) 
    df.to_csv('{}'.format(fullname), index = False)

# %%
outname = '{}_{}_season data.csv'.format(team, season_names[0])
outdir = r'C:\Users\Asus\PycharmProjects\Understat Data Scraper\Data\Team_Data\{}_season'.format(season_names[0])

print(outname + outdir)
# Out:
#   File "<ipython-input-28-3e852ebdadc8>", line 2
#     outdir = 'C:\Users\Asus\PycharmProjects\Understat Data Scraper\Team_Data\{}_season'.format(season_names[0])
#             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
all_team_dicts['Manchester United'].columns
# Out:
# Index(['h_a', 'xG', 'xGA', 'npxG', 'npxGA', 'ppda', 'ppda_allowed', 'deep',
#        'deep_allowed', 'scored', 'missed', 'xpts', 'result', 'date', 'wins',
#        'draws', 'loses', 'pts', 'npxGD', 'ppda_coef', 'oppda_coef'],
#       dtype='object')

# %% [markdown]
# **correcting the format of PPDA and OPDA(PPDA_allowed) to the ratio of PPDA and PPDA_allowed**

# %%
for team, df in all_team_dicts.items():
    all_team_dicts[team]['ppda_coef'] = all_team_dicts[team]['ppda'].apply(lambda x : x['att']/x['def'] if x['def'] != 0 else 0)
    all_team_dicts[team]['oppda_coef'] = all_team_dicts[team]['ppda_allowed'].apply(lambda x : x['att']/x['def'] if x['def'] != 0 else 0)

# %% [markdown]
# **Getting coumns to be averaged and summed**

# %%
cols_to_sum = ['xG', 'xGA', 'npxG', 'npxGA', 'deep', 'deep_allowed', 'scored', 'missed', 'xpts', 'wins', 'draws', 'loses', 'pts', 'npxGD']
cols_to_mean = ['ppda_coef', 'oppda_coef']

# %%
frames = []

for team, df in all_team_dicts.items():
    sum_data = pd.DataFrame(df[cols_to_sum].sum()).transpose() # returns series data, so used transpose() 
    mean_data = pd.DataFrame(df[cols_to_mean].mean()).transpose() # returns series data, so used transpose() 
    sum_mean_data = sum_data.join(mean_data)
    sum_mean_data['team'] = team
    sum_mean_data['matches'] = len(df)
    frames.append(sum_mean_data)
    
final_data = pd.concat(frames, sort = False, ignore_index =True)
# Out:
#            xG        xGA       npxG      npxGA   deep  deep_allowed  scored  \
# 0   33.102671  49.706256  32.341501  46.661579  184.0         237.0    31.0
# 1   44.888185  46.182073  39.560085  43.137400  259.0         245.0    48.0
# 2   54.965667  39.113520  52.682172  37.591178  270.0         183.0    54.0
# 3   48.206401  56.392116  45.161721  53.347435  191.0         287.0    46.0
# 4   38.627729  53.748536  34.821914  48.420396  161.0         283.0    38.0
# 5   37.446153  51.464371  34.401476  48.419705  153.0         313.0    31.0
# 6   44.756683  45.484365  40.052909  40.820304  180.0         258.0    47.0
# 7   68.643320  31.524344  64.740402  29.240835  407.0         171.0    73.0
# 8   46.687234  57.402133  45.164894  53.443827  217.0         316.0    44.0
# 9   52.385284  57.044148  48.427014  51.598938  210.0         232.0    58.0
# 10  69.802591  35.718825  64.474404  33.435352  398.0         171.0    71.0
# 11  40.901235  55.942970  39.378900  54.420634  156.0         310.0    46.0
# 12  46.260597  47.030662  43.977084  43.224882  195.0         239.0    48.0
# 13  40.221386  51.014275  39.460251  47.969675  175.0         239.0    40.0
# 14  51.697226  38.249721  47.130210  35.829400  306.0         201.0    52.0
# 15  75.815441  40.499403  69.609091  37.454762  575.0         144.0    83.0
# 16  54.206860  39.842347  50.401013  36.797702  267.0         194.0    62.0
# 17  32.791033  46.992957  32.029898  44.696850  139.0         261.0    33.0
# 18  39.372649  57.888856  37.089140  54.083013  218.0         258.0    28.0
# 19  45.726091  65.262558  41.907666  62.217878  179.0         298.0    42.0
#
#     missed     xpts  wins  draws  loses   pts      npxGD  ppda_coef  \
# 0     57.0  40.8917  10.0    8.0   20.0  38.0 -14.320078  16.386892
# 1     50.0  50.9105  12.0   11.0   15.0  47.0  -3.577315  10.432774
# 2     33.0  62.8166  18.0    6.0   14.0  60.0  15.090994   9.259540
# 3     55.0  44.6400  11.0    8.0   19.0  41.0  -8.185714  10.229308
# 4     51.0  44.7359  11.0   11.0   16.0  44.0 -13.598482  13.545803
# 5     53.0  44.1821   7.0   17.0   14.0  38.0 -14.018229  11.421301
# 6     51.0  50.5570  13.0    9.0   16.0  48.0  -0.767395  11.577051
# 7     32.0  75.3172  26.0    9.0    3.0  87.0  35.499567  10.942027
# 8     47.0  47.2178  12.0   11.0   15.0  47.0  -8.278933  12.042643
# 9     53.0  48.9361  19.0    7.0   12.0  64.0  -3.171924   8.000237
# 10    36.0  75.1740  22.0    9.0    7.0  75.0  31.039052   8.660596
# 11    49.0  43.3167  16.0    8.0   14.0  56.0 -15.041734  12.826741
# 12    45.0  51.9715  15.0    9.0   14.0  54.0   0.752202  10.405753
# 13    63.0  45.6305  10.0    9.0   19.0  39.0  -8.509424  10.422385
# 14    48.0  61.1673  18.0    8.0   12.0  62.0  11.300810   9.913851
# 15    38.0  73.0982  24.0    7.0    7.0  79.0  32.154329   7.982490
# 16    37.0  63.0327  20.0   10.0    8.0  70.0  13.603311   7.648715
# 17    51.0  41.3213   8.0   11.0   19.0  35.0 -12.666952  14.345146
# 18    53.0  39.7959   7.0   12.0   19.0  33.0 -16.993873  11.460926
# 19    73.0  40.2773   8.0    6.0   24.0  30.0 -20.310212  10.341797
#
#     oppda_coef                  team  matches
# 0    11.065619           Aston Villa       38
# 1    11.682677               Everton       38
# 2    14.879479           Southampton       38
# 3     8.019074             Leicester       38
# 4     9.869703  West Bromwich Albion       38
# 5     8.129492            Sunderland       38
# 6     6.582148        Crystal Palace       38
# 7    13.419520               Chelsea       38
# 8     8.433845              West Ham       38
# 9    11.300694             Tottenham       38
# 10   13.254169               Arsenal       38
# 11   11.455201               Swansea       38
# 12   10.601440                 Stoke       38
# 13    8.840574      Newcastle United       38
# 14   12.121981             Liverpool       38
# 15   15.076979       Manchester City       38
# 16   15.521977     Manchester United       38
# 17   10.021131                  Hull       38
# 18    9.979096               Burnley       38
# 19    7.591177   Queens Park Rangers       38

# %%
final_data = final_data[['team', 'matches', 'wins', 'draws', 'loses', 'scored', 'missed', 'pts','xG', 'npxG', 'xGA', 'npxGA', 'npxGD', 'ppda_coef', 'oppda_coef', 'deep', 'deep_allowed', 'xpts']]
final_data.sort_values('pts', ascending= False, inplace = True)
final_data.reset_index(inplace = True, drop = True)
final_data['position'] = range(1, len(final_data) + 1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# **Finding the difference between "expected" and "real" values**

# %%
final_data.rename(columns ={'missed': 'conceded'}, inplace = True) # renamin 'missed' column to 'conceded'
final_data['xG_diff'] = final_data['xG'] - final_data['scored']
final_data['xGA_diff'] = final_data['xGA'] - final_data['conceded']
final_data['xpts_diff'] = final_data['xpts'] - final_data['pts']

# %% [markdown]
# **converting appropriate columns to integer values**

# %%
cols_to_int = ['wins', 'draws', 'loses', 'scored', 'conceded', 'pts', 'deep', 'deep_allowed']
final_data[cols_to_int] = final_data[cols_to_int].astype(int)

# %% [markdown]
# **Foramtting and changing the order of the dataframe**

# %%
col_order = ['position','team', 'matches', 'wins', 'draws', 'loses', 'scored', 'conceded', 'pts', 'xG', 'xG_diff', 'npxG', 'xGA', 'xGA_diff', 'npxGA', 'npxGD', 'ppda_coef', 'oppda_coef', 'deep', 'deep_allowed', 'xpts', 'xpts_diff']
final_data = final_data[col_order]
pd.options.display.float_format = '{:,.2f}'.format

# %%
final_data
# Out:
#     position                  team  matches  wins  draws  loses  scored  \
# 0          1               Chelsea       38    26      9      3      73
# 1          2       Manchester City       38    24      7      7      83
# 2          3               Arsenal       38    22      9      7      71
# 3          4     Manchester United       38    20     10      8      62
# 4          5             Tottenham       38    19      7     12      58
# 5          6             Liverpool       38    18      8     12      52
# 6          7           Southampton       38    18      6     14      54
# 7          8               Swansea       38    16      8     14      46
# 8          9                 Stoke       38    15      9     14      48
# 9         10        Crystal Palace       38    13      9     16      47
# 10        11               Everton       38    12     11     15      48
# 11        12              West Ham       38    12     11     15      44
# 12        13  West Bromwich Albion       38    11     11     16      38
# 13        14             Leicester       38    11      8     19      46
# 14        15      Newcastle United       38    10      9     19      40
# 15        16           Aston Villa       38    10      8     20      31
# 16        17            Sunderland       38     7     17     14      31
# 17        18                  Hull       38     8     11     19      33
# 18        19               Burnley       38     7     12     19      28
# 19        20   Queens Park Rangers       38     8      6     24      42
#
#     conceded  pts    xG  ...   xGA  xGA_diff  npxGA  npxGD  ppda_coef  \
# 0         32   87 68.64  ... 31.52     -0.48  29.24  35.50      10.94
# 1         38   79 75.82  ... 40.50      2.50  37.45  32.15       7.98
# 2         36   75 69.80  ... 35.72     -0.28  33.44  31.04       8.66
# 3         37   70 54.21  ... 39.84      2.84  36.80  13.60       7.65
# 4         53   64 52.39  ... 57.04      4.04  51.60  -3.17       8.00
# 5         48   62 51.70  ... 38.25     -9.75  35.83  11.30       9.91
# 6         33   60 54.97  ... 39.11      6.11  37.59  15.09       9.26
# 7         49   56 40.90  ... 55.94      6.94  54.42 -15.04      12.83
# 8         45   54 46.26  ... 47.03      2.03  43.22   0.75      10.41
# 9         51   48 44.76  ... 45.48     -5.52  40.82  -0.77      11.58
# 10        50   47 44.89  ... 46.18     -3.82  43.14  -3.58      10.43
# 11        47   47 46.69  ... 57.40     10.40  53.44  -8.28      12.04
# 12        51   44 38.63  ... 53.75      2.75  48.42 -13.60      13.55
# 13        55   41 48.21  ... 56.39      1.39  53.35  -8.19      10.23
# 14        63   39 40.22  ... 51.01    -11.99  47.97  -8.51      10.42
# 15        57   38 33.10  ... 49.71     -7.29  46.66 -14.32      16.39
# 16        53   38 37.45  ... 51.46     -1.54  48.42 -14.02      11.42
# 17        51   35 32.79  ... 46.99     -4.01  44.70 -12.67      14.35
# 18        53   33 39.37  ... 57.89      4.89  54.08 -16.99      11.46
# 19        73   30 45.73  ... 65.26     -7.74  62.22 -20.31      10.34
#
#     oppda_coef  deep  deep_allowed  xpts  xpts_diff
# 0        13.42   407           171 75.32     -11.68
# 1        15.08   575           144 73.10      -5.90
# 2        13.25   398           171 75.17       0.17
# 3        15.52   267           194 63.03      -6.97
# 4        11.30   210           232 48.94     -15.06
# 5        12.12   306           201 61.17      -0.83
# 6        14.88   270           183 62.82       2.82
# 7        11.46   156           310 43.32     -12.68
# 8        10.60   195           239 51.97      -2.03
# 9         6.58   180           258 50.56       2.56
# 10       11.68   259           245 50.91       3.91
# 11        8.43   217           316 47.22       0.22
# 12        9.87   161           283 44.74       0.74
# 13        8.02   191           287 44.64       3.64
# 14        8.84   175           239 45.63       6.63
# 15       11.07   184           237 40.89       2.89
# 16        8.13   153           313 44.18       6.18
# 17       10.02   139           261 41.32       6.32
# 18        9.98   218           258 39.80       6.80
# 19        7.59   179           298 40.28      10.28
#
# [20 rows x 22 columns]

# %% [markdown]
# **Importing players data**
